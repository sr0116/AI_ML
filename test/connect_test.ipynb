# %%
import requests
url = "http://127.0.0.1:8000/app_graphql"
query = """
    query ($limit: Int!) {
      salesViewAll(limit: $limit) {
        # --- 공통: 요약/연도/권역/트리맵 등에서 쓰는 필드들 ---
        year
        monthNo          #  월 번호 추가 (1~12)
        monthName        # (선택) "1월", "2월" 같은 이름도 쓰고 싶으면
        salesAmount
        netProfit
        customerName
        quantity

        # 권역별 막대그래프에서 필요한 컬럼
        region
        sigungu         #  하위 시군구 필드 추가!

        #  트리맵용 3단계 계층 컬럼
        productName
        productCategoryName
        categoryName
      }
    }
    """

# %%
import pandas as pd
resp = requests.post(url, json={'query': query, 'variables': {'limit': 1000}})
data = resp.json()
# sales_view_json = data.get("data").get("salesViewAll") // 여러 방식으로 사용 가능
sales_view_json = data["data"]["salesViewAll"]
df = pd.DataFrame(sales_view_json)
print(df)
# Out:
#      year  monthNo monthName  salesAmount  netProfit customerName  quantity  \
# 0    2018        1   January      28000.0     9700.0          이민수         1
# 1    2018        1   January      20000.0     7200.0          장미연         1
# 2    2018        1   January      77400.0    46200.0          최은주         6
# 3    2018        1   January     143600.0    70000.0          김호준         4
# 4    2018        1   January     172000.0    69600.0          최예나         8
# ..    ...      ...       ...          ...        ...          ...       ...
# 995  2018        7      July       6000.0     3150.0          이재환         3
# 996  2018        8    August     330000.0   144000.0          박주란        15
# 997  2018        8    August      78000.0    60000.0          김우리        12
# 998  2018        8    August      20000.0     7200.0          이지연         1
# 999  2018        8    August       7900.0     4700.0          김민설         1
#
#     region    sigungu              productName productCategoryName  \
# 0       창원  창원시 마산회원구            카메라 수직 촬영 거치대                 삼각대
# 1       창원  창원시 마산합포구  아이패드 에어5/4세대 10.9인치 케이스             케이스/파우치
# 2       대구         동구               미니 무드등 가습기                 가습기
# 3       대구        달성군     고속 충전 보조배터리 20000mAh              휴대폰배터리
# 4       광주         서구             갤럭시워치 가죽 스트랩      웨어러블 디바이스 액세서리
# ..     ...        ...                      ...                 ...
# 995     성남    성남시 중원구        PD C to C 고속충전케이블              휴대폰케이블
# 996     제천        제천시                무선 미니 선풍기                 선풍기
# 997     서울        성동구             C타입 고속충전 케이블              휴대폰케이블
# 998     서울        용산구  아이패드 에어5/4세대 10.9인치 케이스             케이스/파우치
# 999     시흥        시흥시                 애플펜슬 케이스              터치펜/기타
#
#     categoryName
# 0      카메라/캠코더용품
# 1      태블릿PC액세서리
# 2           계절가전
# 3        휴대폰액세서리
# 4        휴대폰액세서리
# ..           ...
# 995      휴대폰액세서리
# 996         계절가전
# 997      휴대폰액세서리
# 998    태블릿PC액세서리
# 999    태블릿PC액세서리
#
# [1000 rows x 12 columns]
